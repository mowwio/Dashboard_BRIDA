# %% [markdown]
# ## Import Library

# %%
import io
import re 
import numpy as np
import pandas as pd
import matplotlib as plt
from typing import Optional

# %% [markdown]
# ## Load Dataset

# %%
file_path = "../data_inovasi.xlsx"
df = pd.read_excel(file_path)
df.head()
# Out:
#    No                                      Judul Inovasi                Pemda  \
# 0   1  POP SURGA (Penghantaran Obat Pasien Sumberglagah)  Provinsi Jawa Timur
# 1   2                 PHEC (Pre Hospital Emergency Care)  Provinsi Jawa Timur
# 2   3                   Naskah Dinas Elektronik (NADINE)  Provinsi Jawa Timur
# 3   4  PERMATA ( Pertanian Ramah Lingkungan menuju Ma...  Provinsi Jawa Timur
# 4   5                                            SIGALON  Provinsi Jawa Timur
#
#                                            Admin OPD      Inisiator  \
# 0  Dinas Kesehatan UPT. RSK Sumberglagah Mojokert...  Kepala Daerah
# 1  Dinas Kesehatan UPT. RSK Sumberglagah Mojokert...            OPD
# 2  Badan Koordinasi Wilayah Pamekasan Provinsi Ja...            OPD
# 3  Dinas Pertanian dan Ketahanan Pangan (jatimpro...            OPD
# 4  Dinas Kesehatan UPT. RS Mata Masyarakat (jatim...            OPD
#
#                 Nama Inisiator  \
# 0  drg. SHINTA SAWITRI, M.Kes
# 1  drg. SHINTA SAWITRI, M.Kes
# 2     Dra. SUFI AGUSTINI, M.Si
# 3                            -
# 4                            -
#
#                                       Bentuk Inovasi        Jenis  \
# 0                           Inovasi pelayanan publik      Digital
# 1                           Inovasi pelayanan publik  Non Digital
# 2            Inovasi tata kelola pemerintahan daerah    Teknologi
# 3  Inovasi Daerah lainnya sesuai dengan Urusan Pe...      Digital
# 4                           Inovasi pelayanan publik      Digital
#
#                                           Asta Cipta Urusan Utama  \
# 0  Memperkuat pembangunan sumber daya manusia (SD...    kesehatan
# 1  Memperkuat pembangunan sumber daya manusia (SD...   pendidikan
# 2  Memperkuat reformasi politik, hukum, dan birok...    kearsipan
# 3                                                  -    pertanian
# 4                                                  -    kesehatan
#
#                           Urusan lain yang beririsan  Kematangan  \
# 0                  pekerjaan umum dan penataan ruang        85.0
# 1                                          kesehatan        92.0
# 2  Fungsi Penunjang lainnya sesuai dengan ketentu...       110.0
# 3                                                NaN        60.0
# 4                                                NaN        52.0
#
#   Tahapan Inovasi Tanggal Input Tanggal Penerapan Tanggal Pengembangan  \
# 0       Penerapan    22-07-2022        29-11-2023                    -
# 1       Penerapan    22-07-2022        24-06-2023                    -
# 2       Penerapan    20-06-2023        31-12-2024           31-12-2024
# 3        Uji Coba    26-06-2023        25-09-2023                    -
# 4       Penerapan    10-07-2023        10-07-2023                    -
#
#                                 Koordinat      Video  \
# 0   -7.60739065953564, 112.54078722662341        Ada
# 1    -7.6073109183015, 112.54072288029913        Ada
# 2  -7.158553824257441, 113.48272568540575        Ada
# 3                                     NaN  Tidak Ada
# 4                                     NaN        Ada
#
#                                           Link Video
# 0        https://www.youtube.com/watch?v=o_TedznOu3U
# 1                       https://youtu.be/TJaII4_0UkI
# 2  https://drive.google.com/file/d/192dhJGWtC4lDc...
# 3                                                  -
# 4  https://drive.google.com/file/d/1JKCIqN4TRVL-O...

# %% [markdown]
# ## Data Checking

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   No                          679 non-null    int64
#  1   Judul Inovasi               679 non-null    object
#  2   Pemda                       679 non-null    object
#  3   Admin OPD                   679 non-null    object
#  4   Inisiator                   679 non-null    object
#  5   Nama Inisiator              679 non-null    object
#  6   Bentuk Inovasi              679 non-null    object
#  7   Jenis                       679 non-null    object
#  8   Asta Cipta                  679 non-null    object
#  9   Urusan Utama                679 non-null    object
#  10  Urusan lain yang beririsan  463 non-null    object
#  11  Kematangan                  679 non-null    float64
#  12  Tahapan Inovasi             679 non-null    object
#  13  Tanggal Input               679 non-null    object
#  14  Tanggal Penerapan           679 non-null    object
#  15  Tanggal Pengembangan        679 non-null    object
#  16  Koordinat                   587 non-null    object
#  17  Video                       679 non-null    object
#  18  Link Video                  679 non-null    object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 100.9+ KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
null_columns = df.isnull().sum()
null_columns[null_columns > 0]
# Out:
# Urusan lain yang beririsan    216
# Koordinat                      92
# dtype: int64

# %%
dash_count = (df == "-").sum()
dash_count[dash_count > 0].sort_values(ascending=False)
# Out:
# Tanggal Pengembangan    294
# Link Video              108
# Asta Cipta               92
# Nama Inisiator           10
# dtype: int64

# %%
# check uniqe value
unique_values = {col: df[col].nunique() for col in df.columns}
unique_values
# Out:
# {'No': 679,
#  'Judul Inovasi': 664,
#  'Pemda': 1,
#  'Admin OPD': 292,
#  'Inisiator': 4,
#  'Nama Inisiator': 552,
#  'Bentuk Inovasi': 3,
#  'Jenis': 3,
#  'Asta Cipta': 9,
#  'Urusan Utama': 31,
#  'Urusan lain yang beririsan': 132,
#  'Kematangan': 89,
#  'Tahapan Inovasi': 3,
#  'Tanggal Input': 80,
#  'Tanggal Penerapan': 378,
#  'Tanggal Pengembangan': 243,
#  'Koordinat': 418,
#  'Video': 2,
#  'Link Video': 569}

# %%
# Unique values for key categorical columns
categorical_cols = [
    "Bentuk Inovasi",
    "Jenis",
    "Tahapan Inovasi",
    "Inisiator",
    "Asta Cipta",
    "Urusan Utama",
    "Urusan lain yang beririsan"
]

for col in categorical_cols:
    print(f"\nDistribusi {col}:")
    temp = df[col].value_counts().reset_index()
    temp.columns = [col, "Jumlah"]
    print(temp)
# Out:
# Distribusi Bentuk Inovasi:
#                                       Bentuk Inovasi  Jumlah
# 0                           Inovasi pelayanan publik     444
# 1  Inovasi Daerah lainnya sesuai dengan Urusan Pe...     185
# 2            Inovasi tata kelola pemerintahan daerah      50
#
# Distribusi Jenis:
#          Jenis  Jumlah
# 0  Non Digital     346
# 1      Digital     234
# 2    Teknologi      99
#
# Distribusi Tahapan Inovasi:
#   Tahapan Inovasi  Jumlah
# 0       Penerapan     648
# 1       Inisiatif      22
# 2        Uji Coba       9
#
# Distribusi Inisiator:
#        Inisiator  Jumlah
# 0            ASN     362
# 1            OPD     226
# 2  Kepala Daerah      49
# 3     Masyarakat      42
#
# Distribusi Asta Cipta:
#                                           Asta Cipta  Jumlah
# 0  Memperkuat pembangunan sumber daya manusia (SD...     400
# 1                                                  -      92
# 2  Meningkatkan lapangan kerja yang berkualitas, ...      62
# 3  Memperkuat penyelarasan kehidupan yang harmoni...      39
# 4  Memperkuat reformasi politik, hukum, dan birok...      35
# 5  Memantapkan sistem pertahanan keamanan negara ...      23
# 6  Membangun dari desa dan dari bawah untuk pemer...      13
# 7  Melanjutkan hilirisasi dan industrialisasi unt...      10
# 8  Memperkokoh ideologi Pancasila, demokrasi, dan...       5
#
# Distribusi Urusan Utama:
#                                          Urusan Utama  Jumlah
# 0                                          pendidikan     381
# 1                                           kesehatan     101
# 2                                              sosial      23
# 3   Fungsi Penunjang lainnya sesuai dengan ketentu...      15
# 4                 koperasi, usaha kecil, dan menengah      14
# 5                                              pangan      13
# 6                   pekerjaan umum dan penataan ruang      12
# 7                                         perhubungan      11
# 8                              kelautan dan perikanan       9
# 9                          komunikasi dan informatika       9
# 10  ketenteraman, ketertiban umum, dan pelindungan...       8
# 11                                   lingkungan hidup       8
# 12                                       tenaga kerja       8
# 13                                          pertanian       8
# 14                                         kebudayaan       7
# 15                           kepemudaan dan olah raga       7
# 16                                          kearsipan       6
# 17                        Penelitian dan Pengembangan       5
# 18                                        Kepegawaian       4
# 19                           Pendidikan dan Pelatihan       4
# 20                   pemberdayaan masyarakat dan Desa       4
# 21                     energi dan sumber daya mineral       3
# 22        pemberdayaan perempuan dan pelindungan anak       3
# 23                                    penanaman modal       3
# 24                                           Keuangan       3
# 25                                        Perencanaan       2
# 26                                        perdagangan       2
# 27                                         pariwisata       2
# 28            perumahan rakyat dan kawasan permukiman       2
# 29                                       perpustakaan       1
# 30     administrasi kependudukan dan pencatatan sipil       1
#
# Distribusi Urusan lain yang beririsan:
#                             Urusan lain yang beririsan  Jumlah
# 0                             Pendidikan dan Pelatihan      95
# 1    Fungsi Penunjang lainnya sesuai dengan ketentu...      32
# 2                                     lingkungan hidup      29
# 3                           komunikasi dan informatika      28
# 4                                               sosial      17
# ..                                                 ...     ...
# 127  pemberdayaan perempuan dan pelindungan anak,Fu...       1
# 128  kepemudaan dan olah raga,Pendidikan dan Pelatihan       1
# 129  tenaga kerja,komunikasi dan informatika,perind...       1
# 130                         lingkungan hidup,pertanian       1
# 131                  pangan,lingkungan hidup,pertanian       1
#
# [132 rows x 2 columns]

# %%
# Total Inovasi
total_inovasi = df["Judul Inovasi"].nunique()
print("Total inovasi:", total_inovasi)
# Out:
# Total inovasi: 664

# %%
print("Jumlah data duplikat:", df.duplicated(keep=False).sum())
# Out:
# Jumlah data duplikat: 0

# %%
# Check data Inovasi terduplikat
df_check = df.copy()
df_check["judul_raw"] = df_check["Judul Inovasi"].astype(str)

df_check["judul_clean"] = (
    df_check["judul_raw"]
    .str.strip()
    .str.replace(r"\s+", " ", regex=True)
)

df_check["judul_norm"] = (
    df_check["judul_clean"]
    .str.lower()
    .str.replace("“", '"')
    .str.replace("”", '"')
    .str.replace("’", "'")
    .str.replace("‘", "'")
    .str.replace(r"[^a-z0-9\s]", "", regex=True)
)

dup_group = (
    df_check
    .groupby("judul_norm")
    .size()
    .reset_index(name="jumlah")
    .query("jumlah > 1")
)

print("Jumlah judul yang terduplikat :", len(dup_group))

dup_norm = df_check[df_check.duplicated(subset=["judul_norm"], keep=False)]
columns = [
    "judul_raw",
    "judul_clean",
    "judul_norm",
    "Admin OPD",
    "Inisiator",
    "Nama Inisiator",
    "Jenis",
    "Kematangan",
    "Tahapan Inovasi",
    "Tanggal Input",
    "Tanggal Penerapan",
    "Tanggal Pengembangan"
]

df_duplicate = (
    dup_norm[columns]
    .sort_values(by=["judul_norm", "Admin OPD"])
    .reset_index(drop=True)
)

df_duplicate
# Out:
# Jumlah judul yang terduplikat : 20
#                                             judul_raw  \
# 0                                        BATA MERDEKA
# 1                                       BATA MERDEKA
# 2                                        DAKSA BUDAYA
# 3                                        DAKSA BUDAYA
# 4   DIGDAYA: Digitalisasi untuk Mewujudkan Kedisip...
# 5   DIGDAYA: Digitalisasi untuk Mewujudkan Kedisip...
# 6   ‘E-KOMITE’ SISTEM MONITORING PELAYANAN PARTISI...
# 7   ‘E-KOMITE’ SISTEM MONITORING PELAYANAN PARTISI...
# 8   “E-PKL (Elektronik Praktik Kerja Lapangan)” SM...
# 9   “E-PKL (Elektronik Praktik Kerja Lapangan)” SM...
# 10                                     GALERY DIGITAL
# 11                                     GALERY DIGITAL
# 12  GERAKAN PENGUATAN LITERASI SEKOLAH BERBASIS DI...
# 13  GERAKAN PENGUATAN LITERASI SEKOLAH BERBASIS DI...
# 14  Legen Tuban (LitErasi, GENeralisasi, dan Tekno...
# 15  ”LEGEN TUBAN” (LitErasi, GENeralisasi, dan Tek...
# 16  PEMBUATAN  TABALIS UNTUK MENINGKATKAN KETERAMP...
# 17  Pembuatan Tabalis Untuk Meningkatkan Keterampi...
# 18                Program KASIKU ( Alikasi KU-Belajar
# 19                Program KASIKU ( Alikasi KU-Belajar
# 20                                       PUSPA LITERA
# 21                                       PUSPA LITERA
# 22                          SEKOLAH SAK NGAJINE (SSN)
# 23                          SEKOLAH SAK NGAJINE (SSN)
# 24               SERGAP - Serangan Gabungan Pembinaan
# 25               SERGAP - Serangan Gabungan Pembinaan
# 26       SI-BECIK (Sekolahku Cantik Berhias Ecobrick)
# 27       SI_BECIK (Sekolahku Cantik Berhias Ecobrick)
# 28                                      SIJAWARA PLUS
# 29                                      SIJAWARA PLUS
# 30  SIPPS 215 (SISTEM INFORMASI POIN PELANGGARAN S...
# 31  SIPPS 215 (SISTEM INFORMASI POIN PELANGGARAN S...
# 32  SIPPS 215 (Sistem Informasi Poin Pelanggaran S...
# 33                                TAMAN PADUKA SANGRA
# 34                                TAMAN PADUKA SANGRA
# 35                                      TARUNA BUDAYA
# 36                                      TARUNA BUDAYA
# 37  TOPCER ‘TEKNOLOGI EMPON CHOPPER’ SOLUSI CERDAS...
# 38  TOPCER ‘TEKNOLOGI EMPON CHOPPER’ SOLUSI CERDAS...
# 39                                            UMISARI
# 40                                            UMISARI
#
#                                           judul_clean  \
# 0                                        BATA MERDEKA
# 1                                        BATA MERDEKA
# 2                                        DAKSA BUDAYA
# 3                                        DAKSA BUDAYA
# 4   DIGDAYA: Digitalisasi untuk Mewujudkan Kedisip...
# 5   DIGDAYA: Digitalisasi untuk Mewujudkan Kedisip...
# 6   ‘E-KOMITE’ SISTEM MONITORING PELAYANAN PARTISI...
# 7   ‘E-KOMITE’ SISTEM MONITORING PELAYANAN PARTISI...
# 8   “E-PKL (Elektronik Praktik Kerja Lapangan)” SM...
# 9   “E-PKL (Elektronik Praktik Kerja Lapangan)” SM...
# 10                                     GALERY DIGITAL
# 11                                     GALERY DIGITAL
# 12  GERAKAN PENGUATAN LITERASI SEKOLAH BERBASIS DI...
# 13  GERAKAN PENGUATAN LITERASI SEKOLAH BERBASIS DI...
# 14  Legen Tuban (LitErasi, GENeralisasi, dan Tekno...
# 15  ”LEGEN TUBAN” (LitErasi, GENeralisasi, dan Tek...
# 16  PEMBUATAN TABALIS UNTUK MENINGKATKAN KETERAMPI...
# 17  Pembuatan Tabalis Untuk Meningkatkan Keterampi...
# 18                Program KASIKU ( Alikasi KU-Belajar
# 19                Program KASIKU ( Alikasi KU-Belajar
# 20                                       PUSPA LITERA
# 21                                       PUSPA LITERA
# 22                          SEKOLAH SAK NGAJINE (SSN)
# 23                          SEKOLAH SAK NGAJINE (SSN)
# 24               SERGAP - Serangan Gabungan Pembinaan
# 25               SERGAP - Serangan Gabungan Pembinaan
# 26       SI-BECIK (Sekolahku Cantik Berhias Ecobrick)
# 27       SI_BECIK (Sekolahku Cantik Berhias Ecobrick)
# 28                                      SIJAWARA PLUS
# 29                                      SIJAWARA PLUS
# 30  SIPPS 215 (SISTEM INFORMASI POIN PELANGGARAN S...
# 31  SIPPS 215 (SISTEM INFORMASI POIN PELANGGARAN S...
# 32  SIPPS 215 (Sistem Informasi Poin Pelanggaran S...
# 33                                TAMAN PADUKA SANGRA
# 34                                TAMAN PADUKA SANGRA
# 35                                      TARUNA BUDAYA
# 36                                      TARUNA BUDAYA
# 37  TOPCER ‘TEKNOLOGI EMPON CHOPPER’ SOLUSI CERDAS...
# 38  TOPCER ‘TEKNOLOGI EMPON CHOPPER’ SOLUSI CERDAS...
# 39                                            UMISARI
# 40                                            UMISARI
#
#                                            judul_norm  \
# 0                                        bata merdeka
# 1                                        bata merdeka
# 2                                        daksa budaya
# 3                                        daksa budaya
# 4   digdaya digitalisasi untuk mewujudkan kedisipl...
# 5   digdaya digitalisasi untuk mewujudkan kedisipl...
# 6   ekomite sistem monitoring pelayanan partisipas...
# 7   ekomite sistem monitoring pelayanan partisipas...
# 8   epkl elektronik praktik kerja lapangan smkn 12...
# 9   epkl elektronik praktik kerja lapangan smkn 12...
# 10                                     galery digital
# 11                                     galery digital
# 12  gerakan penguatan literasi sekolah berbasis di...
# 13  gerakan penguatan literasi sekolah berbasis di...
# 14  legen tuban literasi generalisasi dan teknolog...
# 15  legen tuban literasi generalisasi dan teknolog...
# 16  pembuatan tabalis untuk meningkatkan keterampi...
# 17  pembuatan tabalis untuk meningkatkan keterampi...
# 18                  program kasiku  alikasi kubelajar
# 19                  program kasiku  alikasi kubelajar
# 20                                       puspa litera
# 21                                       puspa litera
# 22                            sekolah sak ngajine ssn
# 23                            sekolah sak ngajine ssn
# 24                sergap  serangan gabungan pembinaan
# 25                sergap  serangan gabungan pembinaan
# 26          sibecik sekolahku cantik berhias ecobrick
# 27          sibecik sekolahku cantik berhias ecobrick
# 28                                      sijawara plus
# 29                                      sijawara plus
# 30  sipps 215 sistem informasi poin pelanggaran si...
# 31  sipps 215 sistem informasi poin pelanggaran si...
# 32  sipps 215 sistem informasi poin pelanggaran si...
# 33                                taman paduka sangra
# 34                                taman paduka sangra
# 35                                      taruna budaya
# 36                                      taruna budaya
# 37  topcer teknologi empon chopper solusi cerdas p...
# 38  topcer teknologi empon chopper solusi cerdas p...
# 39                                            umisari
# 40                                            umisari
#
#                                             Admin OPD   Inisiator  \
# 0      SMA Negeri 1 Jombang (iga2024.sma.n.1.jombang)         ASN
# 1      SMA Negeri 1 Jombang (iga2024.sma.n.1.jombang)         OPD
# 2   Dinas Kebudayaan dan Pariwisata Provinsi Jawa ...         OPD
# 3      admin.jawa.timur (iga2025.provinsi.jawa.timur)         OPD
# 4   SMAN 2 PONOROGO  (jatimprov.dispendik.sman2pon...         ASN
# 5           SMAN 2 PONOROGO (iga2024.sman.2.ponorogo)         ASN
# 6   SMK NEGERI 1 KARE, KAB MADIUN (jatimprov.dispe...         ASN
# 7   SMK NEGERI 1 KARE, KAB MADIUN (jatimprov.dispe...         ASN
# 8           Smkn 12 surabaya (iga2025.smkn12surabaya)         ASN
# 9           Smkn 12 surabaya (iga2025.smkn12surabaya)         ASN
# 10  SMPLB YPABK MUNCAR BANYUWANGI (jatimprov.dispe...  Masyarakat
# 11  SMPLB YPABK MUNCAR BANYUWANGI (jatimprov.dispe...  Masyarakat
# 12            SMAN 3 MAGETAN (iga2024.smkn.3.magetan)         ASN
# 13            SMAN 3 MAGETAN (iga2024.smkn.3.magetan)         ASN
# 14  SMK NEGERI RENGEL TUBAN (iga2024.smkn.rengel.t...         ASN
# 15   SMKN 1 Rengel Tuban (iga2025.smkn1.rengel.tuban)         ASN
# 16  SLB NEGERI 1 SAMBIROTO NGAWI (iga2024.slbn1.sa...  Masyarakat
# 17  SLB NEGERI 1 SAMBIROTO NGAWI (iga2024.slbn1.sa...  Masyarakat
# 18      SMAN 1 SRONO (jatimprov.dispendik.sman1srono)         ASN
# 19      SMAN 1 SRONO (jatimprov.dispendik.sman1srono)         ASN
# 20  SMAN 2 PONOROGO  (jatimprov.dispendik.sman2pon...         ASN
# 21          SMAN 2 PONOROGO (iga2024.sman.2.ponorogo)         ASN
# 22         SLBN 2 KOTA BLITAR (iga2024.slbn.2.blitar)         ASN
# 23         SLBN 2 KOTA BLITAR (iga2024.slbn.2.blitar)         ASN
# 24  Dinas Koperasi, Usaha Kecil dan Menengah Provi...         OPD
# 25  Dinas Koperasi, Usaha Kecil dan Menengah Provi...         OPD
# 26  SMAN 1 Kunir  Lumajang (iga2024.sman.1.kurir.l...         ASN
# 27  SMAN 1 Kunir  Lumajang (iga2024.sman.1.kurir.l...         ASN
# 28  Dinas Koperasi, Usaha Kecil dan Menengah Provi...         OPD
# 29  Dinas Koperasi, Usaha Kecil dan Menengah Provi...         OPD
# 30  SMK NEGERI 1 WATULIMO TRENGGALEK (iga2024.smkn...         ASN
# 31  SMK NEGERI 1 WATULIMO TRENGGALEK (iga2024.smkn...         ASN
# 32  SMK NEGERI 1 WATULIMO TRENGGALEK (iga2024.smkn...         ASN
# 33  SMAN 1 NGRAMBE (jatimprov.dispendik.sman1ngrambe)         ASN
# 34  SMAN 1 NGRAMBE (jatimprov.dispendik.sman1ngrambe)         ASN
# 35  Dinas Kebudayaan dan Pariwisata Provinsi Jawa ...         OPD
# 36     admin.jawa.timur (iga2025.provinsi.jawa.timur)         OPD
# 37  SMK NEGERI 1 KARE, KAB MADIUN (jatimprov.dispe...         ASN
# 38  SMK NEGERI 1 KARE, KAB MADIUN (jatimprov.dispe...         ASN
# 39  Dinas Energi dan Sumber Daya Mineral Provinsi ...         OPD
# 40     admin.jawa.timur (iga2025.provinsi.jawa.timur)         OPD
#
#                                        Nama Inisiator        Jenis  \
# 0                        ZAGLUL RIJAL PASHA, S.Pd DKK  Non Digital
# 1                     ZAGHLUL RIJAL PHASA, S. Pd. DKK  Non Digital
# 2                         Evy Afianasari, S.T., M.M.A      Digital
# 3                            Evy Afianasari, S.T, MMA      Digital
# 4                            Zanwar Sugiartoko, S.Kom      Digital
# 5                            Zanwar Sugiartoko, S.Kom      Digital
# 6                                                   -      Digital
# 7                            SEPTA KRISDIYANTO, M.Pd.      Digital
# 8                                Cone Kustarto Arifin      Digital
# 9                                Cone Kustarto Arifin      Digital
# 10                       LATU METHA MARYA MAHARDIKA P    Teknologi
# 11                       LATU METHA MARYA MAHARDIKA P      Digital
# 12                            Drs. HERY SUBAGYO, M.Pd      Digital
# 13                           Dra. RIFUL HAMIDAH, M.Pd      Digital
# 14                   TRI ERNI HUDAYAH, S. Pd., M. Pd.      Digital
# 15  TRI ERNI HUDAYAH, S.Pd., M.Pd., dan JOKO SUNTH...      Digital
# 16                       SLB NEGERI 1 SAMBIROTO NGAWI  Non Digital
# 17                       SLB Negeri 1 Sambiroto Ngawi  Non Digital
# 18                                             Hadiri      Digital
# 19                                             Hadiri      Digital
# 20                   David Agung Prasetiyoko, S.Pd.I.  Non Digital
# 21                     David Agung Prasetyoko, S.Pd.I  Non Digital
# 22                                      KHOIRUN NISAK  Non Digital
# 23                                KHOIRUN NISAK, S.Pd  Non Digital
# 24                Dr. ENDY ALIM ABDI NUSA S.IP., M.M.      Digital
# 25                Dr. ENDY ALIM ABDI NUSA S.IP., M.M.    Teknologi
# 26                                      Lina Larasati  Non Digital
# 27                                      Lina Larasati  Non Digital
# 28                 Dr. Endy Alim Abdi Nusa, S.IP., MM      Digital
# 29                 Dr. Endy Alim Abdi Nusa, S.IP., MM    Teknologi
# 30  Dr. SANTIKA, S.Pi., M.Si dan WAHYU SETYO LAKSO...      Digital
# 31  Dr. SANTIKA, S.Pi., M.Si dan WAHYU SETYO LAKSO...      Digital
# 32                         WAHYU SETYO LAKSONO, S.Pd.      Digital
# 33                       Alfian Perdhana Putra, S.Pd.      Digital
# 34                       Alfian Perdhana Putra, S.Pd.  Non Digital
# 35                        Evy Afianasari, S.T., M.M.A  Non Digital
# 36                           Evy Afianasari, S.T, MMA  Non Digital
# 37                       ANIK AMBARWATI, S.Pd., M.Si.  Non Digital
# 38                       ANIK AMBARWATI, S.Pd., M.Si.  Non Digital
# 39                                 Putri Setianingsih  Non Digital
# 40                 Dr. NURKHOLIS S.Sos.,Msi,CIPA,CIHM      Digital
#
#     Kematangan Tahapan Inovasi Tanggal Input Tanggal Penerapan  \
# 0          0.0       Penerapan    30-07-2025        01-11-2024
# 1        101.0       Penerapan    01-08-2025        06-08-2024
# 2        111.0       Penerapan    20-08-2025        04-03-2024
# 3          9.0       Penerapan    19-08-2025        02-01-2023
# 4        107.0       Penerapan    29-07-2025        15-07-2024
# 5         99.0       Penerapan    05-08-2024        15-07-2024
# 6          0.0       Penerapan    15-07-2023        27-09-2023
# 7         99.0       Penerapan    25-07-2024        27-09-2023
# 8          0.0       Penerapan    24-07-2025        02-01-2025
# 9         82.0       Penerapan    24-07-2025        07-10-2024
# 10        73.0       Penerapan    07-08-2024        01-06-2023
# 11        66.0       Penerapan    07-08-2024        01-06-2023
# 12       107.0       Penerapan    25-07-2024        01-03-2023
# 13       109.0       Penerapan    13-07-2025        06-05-2024
# 14        95.0       Penerapan    22-07-2024        22-04-2022
# 15       111.0       Penerapan    15-07-2025        21-04-2024
# 16       101.0       Penerapan    26-07-2024        24-08-2023
# 17        15.0       Penerapan    25-07-2025        25-08-2025
# 18         0.0       Penerapan    25-07-2024        18-07-2022
# 19        24.0       Penerapan    29-07-2024        04-07-2022
# 20       103.0       Penerapan    30-07-2025        15-07-2024
# 21        85.0       Penerapan    15-07-2025        15-07-2024
# 22        96.0       Penerapan    29-07-2024        10-07-2023
# 23       104.0       Penerapan    24-07-2025        10-07-2024
# 24        78.0       Penerapan    10-07-2025        02-01-2024
# 25        84.0       Penerapan    10-07-2025        02-01-2024
# 26       109.0       Penerapan    24-07-2024        03-02-2023
# 27       110.0       Penerapan    20-07-2025        03-02-2023
# 28        78.0       Penerapan    10-07-2025        02-01-2024
# 29        83.0       Penerapan    10-07-2025        02-01-2024
# 30       100.0       Penerapan    24-07-2024        04-09-2023
# 31        97.0       Penerapan    05-08-2024        04-09-2023
# 32       110.0       Penerapan    23-07-2025        04-09-2023
# 33        79.0       Penerapan    23-08-2025        09-12-2024
# 34        86.0       Penerapan    23-08-2025        09-12-2024
# 35       107.0       Penerapan    19-08-2025        19-01-2023
# 36         9.0       Penerapan    15-08-2025        01-01-2022
# 37         0.0       Inisiatif    25-07-2025        25-07-2025
# 38        65.0       Penerapan    06-08-2025        01-03-2024
# 39        64.0       Penerapan    08-08-2025        01-01-2024
# 40        85.0       Penerapan    17-07-2024        15-01-2021
#
#    Tanggal Pengembangan
# 0                     -
# 1                     -
# 2            04-03-2024
# 3            02-01-2024
# 4                     -
# 5                     -
# 6                     -
# 7            18-12-2023
# 8                     -
# 9                     -
# 10                    -
# 11                    -
# 12                    -
# 13                    -
# 14           10-07-2023
# 15           21-05-2024
# 16           10-10-2023
# 17           25-08-2025
# 18           02-01-2023
# 19           02-01-2023
# 20                    -
# 21                    -
# 22           10-07-2023
# 23           01-06-2024
# 24                    -
# 25                    -
# 26                    -
# 27                    -
# 28                    -
# 29                    -
# 30                    -
# 31                    -
# 32           02-12-2024
# 33           19-03-2025
# 34                    -
# 35           19-01-2024
# 36           12-03-2024
# 37                    -
# 38                    -
# 39           08-06-2024
# 40           11-01-2023

# %% [markdown]
# # **Preprocessing**

# %%
df_clean = df.copy()

# %%
# merapikan nama kolom (lower case)
df_clean.columns = (
    df_clean.columns
    .str.lower()
    .str.replace(' ', '_')
    .str.replace('.', '', regex=False)
)

string_cols = df_clean.select_dtypes(include="object").columns
for col in string_cols:
    df_clean[col] = df_clean[col].str.strip()

# %%
# Standarisasi missing value ("-" diganti NaN (kecuali link_video))
for col in df_clean.columns:
    if col != "link_video":
        df_clean[col] = df_clean[col].replace("-", np.nan)

# %%
# Konversi column date
date_cols = [
    "tanggal_input",
    "tanggal_pengembangan",
    "tanggal_penerapan"
]

for col in date_cols:
    df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")
# Out:
# C:\Users\Dea\AppData\Local\Temp\ipykernel_29064\1711946224.py:9: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")
# C:\Users\Dea\AppData\Local\Temp\ipykernel_29064\1711946224.py:9: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")
# C:\Users\Dea\AppData\Local\Temp\ipykernel_29064\1711946224.py:9: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")

# %%
# Penanganan kolom kategorikal null
df_clean["urusan_lain_yang_beririsan"] = (
    df_clean["urusan_lain_yang_beririsan"]
    .fillna("Tidak Ada")
)

df_clean["nama_inisiator"] = (
    df_clean["nama_inisiator"]
    .replace("-", pd.NA)
    .fillna("Tidak Disebutkan")
)

df_clean["asta_cipta"] = (
    df_clean["asta_cipta"]
    .replace("-", pd.NA)
    .fillna("Tidak Diisi")
)

# %%
# Konversi numerik column 'kematangan'
df_clean['kematangan'] = pd.to_numeric(
    df_clean['kematangan'],
    errors='coerce'
)

# hanya hapus nilai negatif
df_clean.loc[
    df_clean['kematangan'] < 0,
    'kematangan'
] = np.nan

# %%
# hapus data duplikat berdasarkan nilai kematangan tertinggi
df_clean["judul_key"] = (
    df_clean["judul_inovasi"]
    .astype(str)
    .str.lower()
    .str.strip()
    .str.replace(r"\s+", " ", regex=True)
    .str.replace(r"[^\w\s]", "", regex=True)
)

idx = df_clean.groupby("judul_key")["kematangan"].idxmax()
df_clean = df_clean.loc[idx]
df_clean = df_clean.sort_index()
df_clean = df_clean.drop(columns=["judul_key"])

# %%
# labeling nilai kematangan
def label_kematangan(nilai):
    if pd.isna(nilai):
        return np.nan
    elif 0 <= nilai <= 44.99:
        return "Kurang Inovatif"
    elif 45 <= nilai <= 64.99:
        return "Inovatif"
    elif 65 <= nilai <= 111:
        return "Sangat Inovatif"
    else:
        return np.nan

df_clean["label_kematangan"] = df_clean["kematangan"].apply(label_kematangan)

# %%
# normalisasi koordinat (lat & lon)
def clean_coordinates(df: pd.DataFrame) -> pd.DataFrame:
    df['lat'] = np.nan
    df['lon'] = np.nan
    
    if 'koordinat' not in df.columns:
        return df

    def parse_coord(text):
        if pd.isna(text) or text == '' or text == '-':
            return np.nan, np.nan
            
        text = str(text).strip()
        
        # POLA 1: Format Decimal Standar (e.g., -7.123, 112.123)
        match_decimal = re.search(r'(-?\d+\.\d+)[,\s]+.*?(-?\d+\.\d+)', text)
        if match_decimal:
            return float(match_decimal.group(1)), float(match_decimal.group(2))

        # POLA 2: Format Koma sebagai Desimal (e.g., -7,123, 112,123).731
        match_comma = re.findall(r'(-?\d+)', text)
        if len(match_comma) >= 4:
            try:
                lat = float(f"{match_comma[0]}.{match_comma[1]}")
                lon = float(f"{match_comma[2]}.{match_comma[3]}")
                if -11 <= lat <= -6 and 110 <= lon <= 116: 
                    return lat, lon
            except:
                pass
        
        return np.nan, np.nan

    coords = df['koordinat'].apply(parse_coord)
    
    df['lat'] = [c[0] for c in coords]
    df['lon'] = [c[1] for c in coords]
    
    df.drop(columns=['koordinat'], inplace=True)
    
    return df

df_clean = clean_coordinates(df_clean)

print(df_clean[['lat', 'lon']].info())
print("\nContoh data yang berhasil diekstrak:")
print(df_clean[['lat', 'lon']].dropna().head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 659 entries, 0 to 678
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     522 non-null    float64
#  1   lon     522 non-null    float64
# dtypes: float64(2)
# memory usage: 15.4 KB
# None
#
# Contoh data yang berhasil diekstrak:
#          lat         lon
# 0  -7.607391  112.540787
# 1  -7.607311  112.540723
# 2  -7.158554  113.482726
# 5  -7.325387  112.731079
# 14 -6.993797  110.420183

# %%
# title case
title_case_cols = [
    "bentuk_inovasi",
    "urusan_utama",
    "urusan_lain_yang_beririsan",
]

for col in title_case_cols:
    df_clean[col] = (
        df_clean[col]
        .astype(str)
        .str.strip()
        .replace("nan", pd.NA)   
        .str.title()
    )

# %% [markdown]
# ## Pipeline Preprocessing

# %%
# # pipeline preprocessing (untuk backend)
# def preprocessing_pipeline(df):
#     df_clean = df.copy()

#     # 1. Rapikan nama kolom
#     df_clean.columns = (
#         df_clean.columns
#         .str.lower()
#         .str.replace(" ", "_")
#         .str.replace(".", "", regex=False)
#     )

#     # 2. Trim semua string
#     string_cols = df_clean.select_dtypes(include="object").columns
#     for col in string_cols:
#         df_clean[col] = df_clean[col].astype(str).str.strip()

#     # 3. Standarisasi missing value kecuali link_video
#     for col in df_clean.columns:
#         if col != "link_video":
#             df_clean[col] = df_clean[col].replace("-", np.nan)

#     # 4. Title Case kolom tertentu
#     title_case_cols = [
#         "bentuk_inovasi",
#         "urusan_utama",
#         "urusan_lain_yang_beririsan",
#         "jenis",
#         "tahapan_inovasi",
#         "video"
#     ]
#     for col in title_case_cols:
#         if col in df_clean.columns:
#             df_clean[col] = df_clean[col].str.title()

#     # 5. Pemecahan koordinat
#     if "koordinat" in df_clean.columns:
#         coords = df_clean["koordinat"].astype(str).str.split(",", n=1, expand=True)
#         df_clean["lat"] = pd.to_numeric(coords[0], errors="coerce")
#         df_clean["lon"] = pd.to_numeric(coords[1], errors="coerce")
#         df_clean.drop(columns=["koordinat"], inplace=True)

#     # 6. Hapus duplikat berdasarkan kematangan tertinggi
#     if "kematangan" in df_clean.columns:
#         df_clean = (
#             df_clean.sort_values("kematangan", ascending=False)
#                     .drop_duplicates(subset=["judul_inovasi", "admin_opd"], keep="first")
#         )

#     # 7. Labeling kematangan
#     def label_kematangan(x):
#         if pd.isna(x):
#             return np.nan
#         elif x < 45:
#             return "Kurang Inovatif"
#         elif x < 65:
#             return "Inovatif"
#         else:
#             return "Sangat Inovatif"

#     if "kematangan" in df_clean.columns:
#         df_clean["label_kematangan"] = df_clean["kematangan"].apply(label_kematangan)

#     return df_clean

# df_clean = preprocessing_pipeline(df)

# %%
df_clean.head()
# Out:
#    no                                      judul_inovasi                pemda  \
# 0   1  POP SURGA (Penghantaran Obat Pasien Sumberglagah)  Provinsi Jawa Timur
# 1   2                 PHEC (Pre Hospital Emergency Care)  Provinsi Jawa Timur
# 2   3                   Naskah Dinas Elektronik (NADINE)  Provinsi Jawa Timur
# 3   4  PERMATA ( Pertanian Ramah Lingkungan menuju Ma...  Provinsi Jawa Timur
# 4   5                                            SIGALON  Provinsi Jawa Timur
#
#                                            admin_opd      inisiator  \
# 0  Dinas Kesehatan UPT. RSK Sumberglagah Mojokert...  Kepala Daerah
# 1  Dinas Kesehatan UPT. RSK Sumberglagah Mojokert...            OPD
# 2  Badan Koordinasi Wilayah Pamekasan Provinsi Ja...            OPD
# 3  Dinas Pertanian dan Ketahanan Pangan (jatimpro...            OPD
# 4  Dinas Kesehatan UPT. RS Mata Masyarakat (jatim...            OPD
#
#                nama_inisiator  \
# 0  drg. SHINTA SAWITRI, M.Kes
# 1  drg. SHINTA SAWITRI, M.Kes
# 2    Dra. SUFI AGUSTINI, M.Si
# 3            Tidak Disebutkan
# 4            Tidak Disebutkan
#
#                                       bentuk_inovasi        jenis  \
# 0                           Inovasi Pelayanan Publik      Digital
# 1                           Inovasi Pelayanan Publik  Non Digital
# 2            Inovasi Tata Kelola Pemerintahan Daerah    Teknologi
# 3  Inovasi Daerah Lainnya Sesuai Dengan Urusan Pe...      Digital
# 4                           Inovasi Pelayanan Publik      Digital
#
#                                           asta_cipta urusan_utama  ...  \
# 0  Memperkuat pembangunan sumber daya manusia (SD...    Kesehatan  ...
# 1  Memperkuat pembangunan sumber daya manusia (SD...   Pendidikan  ...
# 2  Memperkuat reformasi politik, hukum, dan birok...    Kearsipan  ...
# 3                                        Tidak Diisi    Pertanian  ...
# 4                                        Tidak Diisi    Kesehatan  ...
#
#   kematangan  tahapan_inovasi tanggal_input tanggal_penerapan  \
# 0       85.0        Penerapan    2022-07-22        2023-11-29
# 1       92.0        Penerapan    2022-07-22        2023-06-24
# 2      110.0        Penerapan    2023-06-20        2024-12-31
# 3       60.0         Uji Coba    2023-06-26        2023-09-25
# 4       52.0        Penerapan    2023-07-10        2023-07-10
#
#   tanggal_pengembangan      video  \
# 0                  NaT        Ada
# 1                  NaT        Ada
# 2           2024-12-31        Ada
# 3                  NaT  Tidak Ada
# 4                  NaT        Ada
#
#                                           link_video label_kematangan  \
# 0        https://www.youtube.com/watch?v=o_TedznOu3U  Sangat Inovatif
# 1                       https://youtu.be/TJaII4_0UkI  Sangat Inovatif
# 2  https://drive.google.com/file/d/192dhJGWtC4lDc...  Sangat Inovatif
# 3                                                  -         Inovatif
# 4  https://drive.google.com/file/d/1JKCIqN4TRVL-O...         Inovatif
#
#         lat         lon
# 0 -7.607391  112.540787
# 1 -7.607311  112.540723
# 2 -7.158554  113.482726
# 3       NaN         NaN
# 4       NaN         NaN
#
# [5 rows x 21 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 659 entries, 0 to 678
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   no                          659 non-null    int64
#  1   judul_inovasi               659 non-null    object
#  2   pemda                       659 non-null    object
#  3   admin_opd                   659 non-null    object
#  4   inisiator                   659 non-null    object
#  5   nama_inisiator              659 non-null    object
#  6   bentuk_inovasi              659 non-null    object
#  7   jenis                       659 non-null    object
#  8   asta_cipta                  659 non-null    object
#  9   urusan_utama                659 non-null    object
#  10  urusan_lain_yang_beririsan  659 non-null    object
#  11  kematangan                  659 non-null    float64
#  12  tahapan_inovasi             659 non-null    object
#  13  tanggal_input               659 non-null    datetime64[ns]
#  14  tanggal_penerapan           659 non-null    datetime64[ns]
#  15  tanggal_pengembangan        377 non-null    datetime64[ns]
#  16  video                       659 non-null    object
#  17  link_video                  659 non-null    object
#  18  label_kematangan            659 non-null    object
#  19  lat                         522 non-null    float64
#  20  lon                         522 non-null    float64
# dtypes: datetime64[ns](3), float64(3), int64(1), object(14)
# memory usage: 113.3+ KB

# %%
# df.to_csv('data_inovasi_clean.csv', index=False)

# %%
df_clean.to_csv("data_inovasi_clean.csv", index=False)
